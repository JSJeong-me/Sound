# %%
# %matplotlib inline

# %% [markdown]
# # Forced Alignment with Wav2Vec2
#
# **Author** [Moto Hira](moto@fb.com)_
#
# This tutorial shows how to align transcript to speech with
# ``torchaudio``, using CTC segmentation algorithm described in
# [CTC-Segmentation of Large Corpora for German End-to-end Speech
# Recognition](https://arxiv.org/abs/2007.09127)_.

# %%
import torch
import torchaudio

print(torch.__version__)
print(torchaudio.__version__)


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# 1.12.1+cu113
# 0.12.1+cu113
# cuda

# %% [markdown]
# ## Overview
#
# The process of alignment looks like the following.
#
# 1. Estimate the frame-wise label probability from audio waveform
# 2. Generate the trellis matrix which represents the probability of
#    labels aligned at time step.
# 3. Find the most likely path from the trellis matrix.
#
# In this example, we use ``torchaudio``\ ’s ``Wav2Vec2`` model for
# acoustic feature extraction.

# %% [markdown]
# ## Preparation
#
# First we import the necessary packages, and fetch data that we work on.

# %%
# %matplotlib inline

from dataclasses import dataclass

import IPython
import matplotlib
import matplotlib.pyplot as plt

matplotlib.rcParams["figure.figsize"] = [16.0, 4.8]

torch.random.manual_seed(0)

# SPEECH_FILE = torchaudio.utils.download_asset("output_waveglow.wav")
SPEECH_FILE = "output_waveglow.wav"

# %% [markdown]
# ## Generate frame-wise label probability
#
# The first step is to generate the label class porbability of each aduio
# frame. We can use a Wav2Vec2 model that is trained for ASR. Here we use
# :py:func:`torchaudio.pipelines.WAV2VEC2_ASR_BASE_960H`.
#
# ``torchaudio`` provides easy access to pretrained models with associated
# labels.
#
# <div class="alert alert-info"><h4>Note</h4><p>In the subsequent sections, we will compute the probability in
#    log-domain to avoid numerical instability. For this purpose, we
#    normalize the ``emission`` with :py:func:`torch.log_softmax`.</p></div>

# %%
bundle = torchaudio.pipelines.WAV2VEC2_ASR_BASE_960H
model = bundle.get_model().to(device)
labels = bundle.get_labels()
with torch.inference_mode():
    waveform, _ = torchaudio.load(SPEECH_FILE)
    emissions, _ = model(waveform.to(device))
    emissions = torch.log_softmax(emissions, dim=-1)

emission = emissions[0].cpu().detach()
# Out:
# Downloading: "https://download.pytorch.org/torchaudio/models/wav2vec2_fairseq_base_ls960_asr_ls960.pth" to /root/.cache/torch/hub/checkpoints/wav2vec2_fairseq_base_ls960_asr_ls960.pth
#   0%|          | 0.00/360M [00:00<?, ?B/s]

# %% [markdown]
# ### Visualization

# %%
print(labels)
plt.imshow(emission.T)
plt.colorbar()
plt.title("Frame-wise class probability")
plt.xlabel("Time")
plt.ylabel("Labels")
plt.show()
# Out:
# ('-', '|', 'E', 'T', 'A', 'O', 'N', 'I', 'H', 'S', 'R', 'D', 'L', 'U', 'M', 'W', 'C', 'F', 'G', 'Y', 'P', 'B', 'V', 'K', "'", 'X', 'J', 'Q', 'Z')

# %% [markdown]
# ## Generate alignment probability (trellis)
#
# From the emission matrix, next we generate the trellis which represents
# the probability of transcript labels occur at each time frame.
#
# Trellis is 2D matrix with time axis and label axis. The label axis
# represents the transcript that we are aligning. In the following, we use
# $t$ to denote the index in time axis and $j$ to denote the
# index in label axis. $c_j$ represents the label at label index
# $j$.
#
# To generate, the probability of time step $t+1$, we look at the
# trellis from time step $t$ and emission at time step $t+1$.
# There are two path to reach to time step $t+1$ with label
# $c_{j+1}$. The first one is the case where the label was
# $c_{j+1}$ at $t$ and there was no label change from
# $t$ to $t+1$. The other case is where the label was
# $c_j$ at $t$ and it transitioned to the next label
# $c_{j+1}$ at $t+1$.
#
# The follwoing diagram illustrates this transition.
#
# <img src="https://download.pytorch.org/torchaudio/tutorial-assets/ctc-forward.png">
#
# Since we are looking for the most likely transitions, we take the more
# likely path for the value of $k_{(t+1, j+1)}$, that is
#
# $k_{(t+1, j+1)} = max( k_{(t, j)} p(t+1, c_{j+1}), k_{(t, j+1)} p(t+1, repeat) )$
#
# where $k$ represents is trellis matrix, and $p(t, c_j)$
# represents the probability of label $c_j$ at time step $t$.
# $repeat$ represents the blank token from CTC formulation. (For the
# detail of CTC algorithm, please refer to the *Sequence Modeling with CTC*
# [[distill.pub](https://distill.pub/2017/ctc/)_])

# %%
# transcript = "I|HAD|THAT|CURIOSITY|BESIDE|ME|AT|THIS|MOMENT"
transcript = "THIS|IS|SUNDAY|THANKS|GOD|IT|IS|SUNDAY"
dictionary = {c: i for i, c in enumerate(labels)}

tokens = [dictionary[c] for c in transcript]
print(list(zip(transcript, tokens)))


def get_trellis(emission, tokens, blank_id=0):
    num_frame = emission.size(0)
    num_tokens = len(tokens)

    # Trellis has extra diemsions for both time axis and tokens.
    # The extra dim for tokens represents <SoS> (start-of-sentence)
    # The extra dim for time axis is for simplification of the code.
    trellis = torch.empty((num_frame + 1, num_tokens + 1))
    trellis[0, 0] = 0
    trellis[1:, 0] = torch.cumsum(emission[:, 0], 0)
    trellis[0, -num_tokens:] = -float("inf")
    trellis[-num_tokens:, 0] = float("inf")

    for t in range(num_frame):
        trellis[t + 1, 1:] = torch.maximum(
            # Score for staying at the same token
            trellis[t, 1:] + emission[t, blank_id],
            # Score for changing to the next token
            trellis[t, :-1] + emission[t, tokens],
        )
    return trellis


trellis = get_trellis(emission, tokens)
# Out:
# [('T', 3), ('H', 8), ('I', 7), ('S', 9), ('|', 1), ('I', 7), ('S', 9), ('|', 1), ('S', 9), ('U', 13), ('N', 6), ('D', 11), ('A', 4), ('Y', 19), ('|', 1), ('T', 3), ('H', 8), ('A', 4), ('N', 6), ('K', 23), ('S', 9), ('|', 1), ('G', 18), ('O', 5), ('D', 11), ('|', 1), ('I', 7), ('T', 3), ('|', 1), ('I', 7), ('S', 9), ('|', 1), ('S', 9), ('U', 13), ('N', 6), ('D', 11), ('A', 4), ('Y', 19)]

# %% [markdown]
# ### Visualization

# %%
plt.imshow(trellis[1:, 1:].T, origin="lower")
plt.annotate("- Inf", (trellis.size(1) / 5, trellis.size(1) / 1.5))
plt.colorbar()
plt.show()

# %% [markdown]
# In the above visualization, we can see that there is a trace of high
# probability crossing the matrix diagonally.

# %% [markdown]
# ## Find the most likely path (backtracking)
#
# Once the trellis is generated, we will traverse it following the
# elements with high probability.
#
# We will start from the last label index with the time step of highest
# probability, then, we traverse back in time, picking stay
# ($c_j \rightarrow c_j$) or transition
# ($c_j \rightarrow c_{j+1}$), based on the post-transition
# probability $k_{t, j} p(t+1, c_{j+1})$ or
# $k_{t, j+1} p(t+1, repeat)$.
#
# Transition is done once the label reaches the beginning.
#
# The trellis matrix is used for path-finding, but for the final
# probability of each segment, we take the frame-wise probability from
# emission matrix.

# %%
@dataclass
class Point:
    token_index: int
    time_index: int
    score: float


def backtrack(trellis, emission, tokens, blank_id=0):
    # Note:
    # j and t are indices for trellis, which has extra dimensions
    # for time and tokens at the beginning.
    # When referring to time frame index `T` in trellis,
    # the corresponding index in emission is `T-1`.
    # Similarly, when referring to token index `J` in trellis,
    # the corresponding index in transcript is `J-1`.
    j = trellis.size(1) - 1
    t_start = torch.argmax(trellis[:, j]).item()

    path = []
    for t in range(t_start, 0, -1):
        # 1. Figure out if the current position was stay or change
        # Note (again):
        # `emission[J-1]` is the emission at time frame `J` of trellis dimension.
        # Score for token staying the same from time frame J-1 to T.
        stayed = trellis[t - 1, j] + emission[t - 1, blank_id]
        # Score for token changing from C-1 at T-1 to J at T.
        changed = trellis[t - 1, j - 1] + emission[t - 1, tokens[j - 1]]

        # 2. Store the path with frame-wise probability.
        prob = emission[t - 1, tokens[j - 1] if changed > stayed else 0].exp().item()
        # Return token index and time index in non-trellis coordinate.
        path.append(Point(j - 1, t - 1, prob))

        # 3. Update the token
        if changed > stayed:
            j -= 1
            if j == 0:
                break
    else:
        raise ValueError("Failed to align")
    return path[::-1]


path = backtrack(trellis, emission, tokens)
for p in path:
    print(p)
# Out:
# Point(token_index=0, time_index=2, score=0.9947651624679565)
# Point(token_index=1, time_index=3, score=0.9972978234291077)
# Point(token_index=1, time_index=4, score=0.9999756813049316)
# Point(token_index=1, time_index=5, score=0.9999477863311768)
# Point(token_index=1, time_index=6, score=0.9999374151229858)
# Point(token_index=2, time_index=7, score=0.9954231381416321)
# Point(token_index=2, time_index=8, score=0.15608331561088562)
# Point(token_index=3, time_index=9, score=0.9937744140625)
# Point(token_index=3, time_index=10, score=0.9994338154792786)
# Point(token_index=3, time_index=11, score=0.9999215602874756)
# Point(token_index=4, time_index=12, score=0.9705998301506042)
# Point(token_index=4, time_index=13, score=0.09818286448717117)
# Point(token_index=4, time_index=14, score=0.9996572732925415)
# Point(token_index=4, time_index=15, score=0.9997240900993347)
# Point(token_index=4, time_index=16, score=0.9997413754463196)
# Point(token_index=4, time_index=17, score=0.9988456964492798)
# Point(token_index=5, time_index=18, score=0.9982777833938599)
# Point(token_index=6, time_index=19, score=0.9984700083732605)
# Point(token_index=6, time_index=20, score=0.998530387878418)
# Point(token_index=6, time_index=21, score=0.03264082968235016)
# Point(token_index=7, time_index=22, score=0.9790935516357422)
# Point(token_index=7, time_index=23, score=0.9795668721199036)
# Point(token_index=7, time_index=24, score=0.9999921321868896)
# Point(token_index=7, time_index=25, score=0.9999954700469971)
# Point(token_index=7, time_index=26, score=0.9999964237213135)
# Point(token_index=7, time_index=27, score=0.9999957084655762)
# Point(token_index=7, time_index=28, score=0.020407669246196747)
# Point(token_index=8, time_index=29, score=0.9982843995094299)
# Point(token_index=8, time_index=30, score=0.9993547797203064)
# Point(token_index=8, time_index=31, score=0.9999817609786987)
# Point(token_index=8, time_index=32, score=0.9999750852584839)
# Point(token_index=8, time_index=33, score=0.9999765157699585)
# Point(token_index=8, time_index=34, score=0.9999809265136719)
# Point(token_index=8, time_index=35, score=0.9999830722808838)
# Point(token_index=9, time_index=36, score=0.9986978769302368)
# Point(token_index=9, time_index=37, score=0.5570542216300964)
# Point(token_index=9, time_index=38, score=0.48290005326271057)
# Point(token_index=10, time_index=39, score=0.9993875026702881)
# Point(token_index=10, time_index=40, score=0.999416708946228)
# Point(token_index=10, time_index=41, score=0.9998063445091248)
# Point(token_index=10, time_index=42, score=0.9988518953323364)
# Point(token_index=10, time_index=43, score=0.9980472326278687)
# Point(token_index=10, time_index=44, score=0.9993519186973572)
# Point(token_index=11, time_index=45, score=0.9998667240142822)
# Point(token_index=11, time_index=46, score=0.994644284248352)
# Point(token_index=11, time_index=47, score=0.9998962879180908)
# Point(token_index=11, time_index=48, score=0.9999555349349976)
# Point(token_index=11, time_index=49, score=0.9999761581420898)
# Point(token_index=11, time_index=50, score=0.999993085861206)
# Point(token_index=11, time_index=51, score=0.9974989295005798)
# Point(token_index=12, time_index=52, score=0.9993268251419067)
# Point(token_index=13, time_index=53, score=0.9947677850723267)
# Point(token_index=13, time_index=54, score=0.0072309719398617744)
# Point(token_index=13, time_index=55, score=0.9764763712882996)
# Point(token_index=13, time_index=56, score=0.00520654022693634)
# Point(token_index=13, time_index=57, score=2.7399955797591247e-06)
# Point(token_index=14, time_index=58, score=0.9951659440994263)
# Point(token_index=14, time_index=59, score=2.017637962126173e-05)
# Point(token_index=14, time_index=60, score=0.9222807288169861)
# Point(token_index=14, time_index=61, score=0.9999979734420776)
# Point(token_index=14, time_index=62, score=0.9999982118606567)
# Point(token_index=14, time_index=63, score=0.9999985694885254)
# Point(token_index=14, time_index=64, score=0.9999988079071045)
# Point(token_index=14, time_index=65, score=0.9999991655349731)
# Point(token_index=14, time_index=66, score=0.9999991655349731)
# Point(token_index=14, time_index=67, score=0.9999991655349731)
# Point(token_index=14, time_index=68, score=0.9999990463256836)
# Point(token_index=14, time_index=69, score=0.9999991655349731)
# Point(token_index=14, time_index=70, score=0.999997615814209)
# Point(token_index=14, time_index=71, score=0.9999990463256836)
# Point(token_index=14, time_index=72, score=0.999998927116394)
# Point(token_index=14, time_index=73, score=0.9999990463256836)
# Point(token_index=14, time_index=74, score=0.999997615814209)
# Point(token_index=14, time_index=75, score=0.9999992847442627)
# Point(token_index=14, time_index=76, score=0.9999984502792358)
# Point(token_index=14, time_index=77, score=0.999997615814209)
# Point(token_index=14, time_index=78, score=0.9999994039535522)
# Point(token_index=14, time_index=79, score=0.9999995231628418)
# Point(token_index=14, time_index=80, score=0.999997615814209)
# Point(token_index=14, time_index=81, score=0.999997615814209)
# Point(token_index=14, time_index=82, score=0.9999995231628418)
# Point(token_index=14, time_index=83, score=0.9999994039535522)
# Point(token_index=14, time_index=84, score=0.999997615814209)
# Point(token_index=14, time_index=85, score=0.9999995231628418)
# Point(token_index=14, time_index=86, score=0.999997615814209)
# Point(token_index=14, time_index=87, score=0.999997615814209)
# Point(token_index=14, time_index=88, score=0.9999994039535522)
# Point(token_index=14, time_index=89, score=0.9999992847442627)
# Point(token_index=14, time_index=90, score=0.9999990463256836)
# Point(token_index=14, time_index=91, score=0.999997615814209)
# Point(token_index=14, time_index=92, score=0.9999988079071045)
# Point(token_index=14, time_index=93, score=0.999998927116394)
# Point(token_index=14, time_index=94, score=0.9999986886978149)
# Point(token_index=14, time_index=95, score=0.9999974966049194)
# Point(token_index=14, time_index=96, score=0.999997615814209)
# Point(token_index=14, time_index=97, score=0.9999971389770508)
# Point(token_index=14, time_index=98, score=0.9999972581863403)
# Point(token_index=14, time_index=99, score=0.9999977350234985)
# Point(token_index=14, time_index=100, score=0.9999978542327881)
# Point(token_index=15, time_index=101, score=0.9993172883987427)
# Point(token_index=16, time_index=102, score=0.9995773434638977)
# Point(token_index=16, time_index=103, score=0.9942727088928223)
# Point(token_index=16, time_index=104, score=0.9999967813491821)
# Point(token_index=16, time_index=105, score=0.9999974966049194)
# Point(token_index=16, time_index=106, score=0.9999985694885254)
# Point(token_index=16, time_index=107, score=0.9999963045120239)
# Point(token_index=17, time_index=108, score=0.9998805522918701)
# Point(token_index=17, time_index=109, score=0.9916391968727112)
# Point(token_index=18, time_index=110, score=0.9998283386230469)
# Point(token_index=18, time_index=111, score=0.0017770588165149093)
# Point(token_index=18, time_index=112, score=0.9999990463256836)
# Point(token_index=19, time_index=113, score=0.9999638795852661)
# Point(token_index=19, time_index=114, score=0.9998080134391785)
# Point(token_index=19, time_index=115, score=0.9998910427093506)
# Point(token_index=19, time_index=116, score=0.9998769760131836)
# Point(token_index=19, time_index=117, score=0.9997133612632751)
# Point(token_index=19, time_index=118, score=0.010081203654408455)
# Point(token_index=20, time_index=119, score=0.9990678429603577)
# Point(token_index=20, time_index=120, score=0.925126314163208)
# Point(token_index=21, time_index=121, score=0.9906206130981445)
# Point(token_index=21, time_index=122, score=0.9991942048072815)
# Point(token_index=21, time_index=123, score=0.999984622001648)
# Point(token_index=21, time_index=124, score=0.999993085861206)
# Point(token_index=21, time_index=125, score=0.9999969005584717)
# Point(token_index=21, time_index=126, score=0.9999943971633911)
# Point(token_index=22, time_index=127, score=0.999945878982544)
# Point(token_index=22, time_index=128, score=0.9999639987945557)
# Point(token_index=22, time_index=129, score=0.999987006187439)
# Point(token_index=22, time_index=130, score=0.9999860525131226)
# Point(token_index=22, time_index=131, score=0.9999837875366211)
# Point(token_index=22, time_index=132, score=0.99997878074646)
# Point(token_index=22, time_index=133, score=0.9999731779098511)
# Point(token_index=22, time_index=134, score=0.9999678134918213)
# Point(token_index=22, time_index=135, score=0.9999648332595825)
# Point(token_index=22, time_index=136, score=0.9991274476051331)
# Point(token_index=23, time_index=137, score=0.9983057975769043)
# Point(token_index=23, time_index=138, score=0.9986777901649475)
# Point(token_index=23, time_index=139, score=0.9978047013282776)
# Point(token_index=23, time_index=140, score=0.9991409778594971)
# Point(token_index=24, time_index=141, score=0.9974580407142639)
# Point(token_index=24, time_index=142, score=0.9896426796913147)
# Point(token_index=24, time_index=143, score=0.9993942975997925)
# Point(token_index=24, time_index=144, score=0.9976345300674438)
# Point(token_index=24, time_index=145, score=0.057954221963882446)
# Point(token_index=25, time_index=146, score=0.9784227013587952)
# Point(token_index=26, time_index=147, score=0.8659346103668213)
# Point(token_index=27, time_index=148, score=0.9051593542098999)
# Point(token_index=27, time_index=149, score=0.00564377149567008)
# Point(token_index=28, time_index=150, score=0.9970434308052063)
# Point(token_index=28, time_index=151, score=0.027952449396252632)
# Point(token_index=28, time_index=152, score=0.9878931641578674)
# Point(token_index=28, time_index=153, score=0.9994922876358032)
# Point(token_index=28, time_index=154, score=0.0258382149040699)
# Point(token_index=28, time_index=155, score=0.9996910095214844)
# Point(token_index=28, time_index=156, score=0.9998224377632141)
# Point(token_index=29, time_index=157, score=0.008152947761118412)
# Point(token_index=29, time_index=158, score=0.19399943947792053)
# Point(token_index=29, time_index=159, score=0.9940035939216614)
# Point(token_index=29, time_index=160, score=0.9509612321853638)
# Point(token_index=30, time_index=161, score=0.14872117340564728)
# Point(token_index=30, time_index=162, score=0.9730432629585266)
# Point(token_index=30, time_index=163, score=0.8064125180244446)
# Point(token_index=31, time_index=164, score=0.9855096340179443)
# Point(token_index=31, time_index=165, score=0.9954402446746826)
# Point(token_index=31, time_index=166, score=0.9999901056289673)
# Point(token_index=31, time_index=167, score=0.9999439716339111)
# Point(token_index=32, time_index=168, score=0.9998263716697693)
# Point(token_index=32, time_index=169, score=0.9999188184738159)
# Point(token_index=32, time_index=170, score=0.9999260902404785)
# Point(token_index=32, time_index=171, score=0.9999077320098877)
# Point(token_index=32, time_index=172, score=0.999925971031189)
# Point(token_index=32, time_index=173, score=0.9999476671218872)
# Point(token_index=32, time_index=174, score=0.9999371767044067)
# Point(token_index=33, time_index=175, score=0.9966828227043152)
# Point(token_index=33, time_index=176, score=0.9433455467224121)
# Point(token_index=33, time_index=177, score=0.9995643496513367)
# Point(token_index=34, time_index=178, score=0.9977889060974121)
# Point(token_index=34, time_index=179, score=0.993261992931366)
# Point(token_index=34, time_index=180, score=0.9996224641799927)
# Point(token_index=34, time_index=181, score=0.9989379048347473)
# Point(token_index=34, time_index=182, score=0.9957886338233948)
# Point(token_index=34, time_index=183, score=0.9931967258453369)
# Point(token_index=34, time_index=184, score=0.9984903335571289)
# Point(token_index=35, time_index=185, score=0.999768078327179)
# Point(token_index=35, time_index=186, score=0.9992940425872803)
# Point(token_index=35, time_index=187, score=0.9998629093170166)
# Point(token_index=35, time_index=188, score=0.9999194145202637)
# Point(token_index=35, time_index=189, score=0.9999566078186035)
# Point(token_index=35, time_index=190, score=0.9999815225601196)
# Point(token_index=35, time_index=191, score=0.9999862909317017)
# Point(token_index=35, time_index=192, score=0.9835857152938843)
# Point(token_index=36, time_index=193, score=0.9988241791725159)
# Point(token_index=37, time_index=194, score=0.8788512349128723)

# %% [markdown]
# ### Visualization

# %%
def plot_trellis_with_path(trellis, path):
    # To plot trellis with path, we take advantage of 'nan' value
    trellis_with_path = trellis.clone()
    for _, p in enumerate(path):
        trellis_with_path[p.time_index, p.token_index] = float("nan")
    plt.imshow(trellis_with_path[1:, 1:].T, origin="lower")


plot_trellis_with_path(trellis, path)
plt.title("The path found by backtracking")
plt.show()

# %% [markdown]
# Looking good. Now this path contains repetations for the same labels, so
# let’s merge them to make it close to the original transcript.
#
# When merging the multiple path points, we simply take the average
# probability for the merged segments.

# %%
# Merge the labels
@dataclass
class Segment:
    label: str
    start: int
    end: int
    score: float

    def __repr__(self):
        return f"{self.label}\t({self.score:4.2f}): [{self.start:5d}, {self.end:5d})"

    @property
    def length(self):
        return self.end - self.start


def merge_repeats(path):
    i1, i2 = 0, 0
    segments = []
    while i1 < len(path):
        while i2 < len(path) and path[i1].token_index == path[i2].token_index:
            i2 += 1
        score = sum(path[k].score for k in range(i1, i2)) / (i2 - i1)
        segments.append(
            Segment(
                transcript[path[i1].token_index],
                path[i1].time_index,
                path[i2 - 1].time_index + 1,
                score,
            )
        )
        i1 = i2
    return segments


segments = merge_repeats(path)
for seg in segments:
    print(seg)
# Out:
# T	(0.99): [    2,     3)
# H	(1.00): [    3,     7)
# I	(0.58): [    7,     9)
# S	(1.00): [    9,    12)
# |	(0.84): [   12,    18)
# I	(1.00): [   18,    19)
# S	(0.68): [   19,    22)
# |	(0.85): [   22,    29)
# S	(1.00): [   29,    36)
# U	(0.68): [   36,    39)
# N	(1.00): [   39,    45)
# D	(1.00): [   45,    52)
# A	(1.00): [   52,    53)
# Y	(0.40): [   53,    58)
# |	(0.97): [   58,   101)
# T	(1.00): [  101,   102)
# H	(1.00): [  102,   108)
# A	(1.00): [  108,   110)
# N	(0.67): [  110,   113)
# K	(0.83): [  113,   119)
# S	(0.96): [  119,   121)
# |	(1.00): [  121,   127)
# G	(1.00): [  127,   137)
# O	(1.00): [  137,   141)
# D	(0.81): [  141,   146)
# |	(0.98): [  146,   147)
# I	(0.87): [  147,   148)
# T	(0.46): [  148,   150)
# |	(0.72): [  150,   157)
# I	(0.54): [  157,   161)
# S	(0.64): [  161,   164)
# |	(1.00): [  164,   168)
# S	(1.00): [  168,   175)
# U	(0.98): [  175,   178)
# N	(1.00): [  178,   185)
# D	(1.00): [  185,   193)
# A	(1.00): [  193,   194)
# Y	(0.88): [  194,   195)

# %% [markdown]
# ### Visualization

# %%
def plot_trellis_with_segments(trellis, segments, transcript):
    # To plot trellis with path, we take advantage of 'nan' value
    trellis_with_path = trellis.clone()
    for i, seg in enumerate(segments):
        if seg.label != "|":
            trellis_with_path[seg.start + 1 : seg.end + 1, i + 1] = float("nan")

    fig, [ax1, ax2] = plt.subplots(2, 1, figsize=(16, 9.5))
    ax1.set_title("Path, label and probability for each label")
    ax1.imshow(trellis_with_path.T, origin="lower")
    ax1.set_xticks([])

    for i, seg in enumerate(segments):
        if seg.label != "|":
            ax1.annotate(seg.label, (seg.start + 0.7, i + 0.3), weight="bold")
            ax1.annotate(f"{seg.score:.2f}", (seg.start - 0.3, i + 4.3))

    ax2.set_title("Label probability with and without repetation")
    xs, hs, ws = [], [], []
    for seg in segments:
        if seg.label != "|":
            xs.append((seg.end + seg.start) / 2 + 0.4)
            hs.append(seg.score)
            ws.append(seg.end - seg.start)
            ax2.annotate(seg.label, (seg.start + 0.8, -0.07), weight="bold")
    ax2.bar(xs, hs, width=ws, color="gray", alpha=0.5, edgecolor="black")

    xs, hs = [], []
    for p in path:
        label = transcript[p.token_index]
        if label != "|":
            xs.append(p.time_index + 1)
            hs.append(p.score)

    ax2.bar(xs, hs, width=0.5, alpha=0.5)
    ax2.axhline(0, color="black")
    ax2.set_xlim(ax1.get_xlim())
    ax2.set_ylim(-0.1, 1.1)


plot_trellis_with_segments(trellis, segments, transcript)
plt.tight_layout()
plt.show()

# %% [markdown]
# Looks good. Now let’s merge the words. The Wav2Vec2 model uses ``'|'``
# as the word boundary, so we merge the segments before each occurance of
# ``'|'``.
#
# Then, finally, we segment the original audio into segmented audio and
# listen to them to see if the segmentation is correct.

# %%
# Merge words
def merge_words(segments, separator="|"):
    words = []
    i1, i2 = 0, 0
    while i1 < len(segments):
        if i2 >= len(segments) or segments[i2].label == separator:
            if i1 != i2:
                segs = segments[i1:i2]
                word = "".join([seg.label for seg in segs])
                score = sum(seg.score * seg.length for seg in segs) / sum(seg.length for seg in segs)
                words.append(Segment(word, segments[i1].start, segments[i2 - 1].end, score))
            i1 = i2 + 1
            i2 = i1
        else:
            i2 += 1
    return words


word_segments = merge_words(segments)
for word in word_segments:
    print(word)
# Out:
# THIS	(0.91): [    2,    12)
# IS	(0.76): [   18,    22)
# SUNDAY	(0.86): [   29,    58)
# THANKS	(0.90): [  101,   121)
# GOD	(0.95): [  127,   146)
# IT	(0.59): [  147,   150)
# IS	(0.58): [  157,   164)
# SUNDAY	(0.99): [  168,   195)

# %% [markdown]
# ### Visualization

# %%
def plot_alignments(trellis, segments, word_segments, waveform):
    trellis_with_path = trellis.clone()
    for i, seg in enumerate(segments):
        if seg.label != "|":
            trellis_with_path[seg.start + 1 : seg.end + 1, i + 1] = float("nan")

    fig, [ax1, ax2] = plt.subplots(2, 1, figsize=(16, 9.5))

    ax1.imshow(trellis_with_path[1:, 1:].T, origin="lower")
    ax1.set_xticks([])
    ax1.set_yticks([])

    for word in word_segments:
        ax1.axvline(word.start - 0.5)
        ax1.axvline(word.end - 0.5)

    for i, seg in enumerate(segments):
        if seg.label != "|":
            ax1.annotate(seg.label, (seg.start, i + 0.3))
            ax1.annotate(f"{seg.score:.2f}", (seg.start, i + 4), fontsize=8)

    # The original waveform
    ratio = waveform.size(0) / (trellis.size(0) - 1)
    ax2.plot(waveform)
    for word in word_segments:
        x0 = ratio * word.start
        x1 = ratio * word.end
        ax2.axvspan(x0, x1, alpha=0.1, color="red")
        ax2.annotate(f"{word.score:.2f}", (x0, 0.8))

    for seg in segments:
        if seg.label != "|":
            ax2.annotate(seg.label, (seg.start * ratio, 0.9))
    xticks = ax2.get_xticks()
    plt.xticks(xticks, xticks / bundle.sample_rate)
    ax2.set_xlabel("time [second]")
    ax2.set_yticks([])
    ax2.set_ylim(-1.0, 1.0)
    ax2.set_xlim(0, waveform.size(-1))


plot_alignments(
    trellis,
    segments,
    word_segments,
    waveform[0],
)
plt.show()

# %%
# A trick to embed the resulting audio to the generated file.
# `IPython.display.Audio` has to be the last call in a cell,
# and there should be only one call par cell.
def display_segment(i):
    ratio = waveform.size(1) / (trellis.size(0) - 1)
    word = word_segments[i]
    x0 = int(ratio * word.start)
    x1 = int(ratio * word.end)
    print(f"{word.label} ({word.score:.2f}): {x0 / bundle.sample_rate:.3f} - {x1 / bundle.sample_rate:.3f} sec")
    segment = waveform[:, x0:x1]
    return IPython.display.Audio(segment.numpy(), rate=bundle.sample_rate)

# %%
# Generate the audio for each segment
print(transcript)
IPython.display.Audio(SPEECH_FILE)
# Out:
# THIS|IS|SUNDAY|THANKS|GOD|IT|IS|SUNDAY
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
display_segment(0)
# Out:
# THIS (0.91): 0.040 - 0.241 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
display_segment(1)
# Out:
# IS (0.76): 0.361 - 0.442 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
display_segment(2)
# Out:
# SUNDAY (0.86): 0.582 - 1.164 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
display_segment(3)
# Out:
# THANKS (0.90): 2.028 - 2.429 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
display_segment(4)
# Out:
# GOD (0.95): 2.550 - 2.931 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
display_segment(5)
# Out:
# IT (0.59): 2.951 - 3.011 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
display_segment(6)
# Out:
# IS (0.58): 3.152 - 3.292 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
display_segment(7)
# Out:
# SUNDAY (0.99): 3.373 - 3.915 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Conclusion
#
# In this tutorial, we looked how to use torchaudio’s Wav2Vec2 model to
# perform CTC segmentation for forced alignment.
