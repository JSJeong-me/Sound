# %% [markdown]
# ### MelSpectrum to Pandas DataFrame Profiling

# %%
import pandas as pd
import numpy as np
import pandas_profiling
# %matplotlib.inline

# %%
df = pd.read_csv("C:\\Users\\heine\\Desktop\\melspectrum-andre.csv", delimiter=',', index_col=0)
df.head()
# Out:
#                  1         2         3         4         5         6  \
# 0
# 0.071488  0.112931  0.087363  0.114844  0.151973  0.114518  0.115065
# 0.327453  0.696546  0.495970  0.418385  1.817774  2.455715  1.712777
# 0.310112  0.253482  0.120895  0.398074  0.784521  0.688576  0.500470
# 0.010208  0.109415  0.239718  0.186538  0.302518  0.280699  0.112543
# 0.053919  0.066492  0.071958  0.025981  0.068463  0.049908  0.037846
#
#                  7         8         9        10  ...      5761      5762  \
# 0                                                 ...
# 0.071488  0.115468  0.104206  0.104113  0.093710  ...  0.042560  0.037324
# 0.327453  0.606350  0.584379  0.968676  1.089640  ...  0.346353  0.281938
# 0.310112  0.110619  0.092076  0.166762  0.210603  ...  0.218074  0.236837
# 0.010208  0.044169  0.065775  0.096242  0.129118  ...  1.059681  1.306099
# 0.053919  0.019698  0.015135  0.012108  0.029974  ...  0.155997  0.195443
#
# ...

# %%
df.describe()
# Out:
#                 1             2             3             4             5  \
# count  128.000000  1.280000e+02  1.280000e+02  1.280000e+02  1.280000e+02
# mean     0.211871  2.440230e-01  3.226298e-01  4.783341e-01  5.158671e-01
# std      1.196340  1.472258e+00  2.128351e+00  2.943198e+00  3.225858e+00
# min      0.000002  6.978904e-08  2.014720e-07  2.669412e-07  2.072597e-07
# 25%      0.000008  6.137136e-06  9.130812e-06  1.103672e-05  6.918623e-06
# 50%      0.000084  1.030302e-04  1.411130e-04  1.143990e-04  1.392331e-04
# 75%      0.004588  1.739567e-03  2.714861e-03  4.280120e-03  2.943818e-03
# max     10.154382  1.401046e+01  2.264048e+01  2.333089e+01  3.149347e+01
#
#                   6             7             8             9            10  \
# count  1.280000e+02  1.280000e+02  1.280000e+02  1.280000e+02  1.280000e+02
# mean   5.578225e-01  5.777135e-01  6.104847e-01  6.568749e-01  7.441649e-01
# ...

# %%
df=df.iloc[:,0:299]

# %%
df.describe()
# Out:
#                 1             2             3             4             5  \
# count  128.000000  1.280000e+02  1.280000e+02  1.280000e+02  1.280000e+02
# mean     0.211871  2.440230e-01  3.226298e-01  4.783341e-01  5.158671e-01
# std      1.196340  1.472258e+00  2.128351e+00  2.943198e+00  3.225858e+00
# min      0.000002  6.978904e-08  2.014720e-07  2.669412e-07  2.072597e-07
# 25%      0.000008  6.137136e-06  9.130812e-06  1.103672e-05  6.918623e-06
# 50%      0.000084  1.030302e-04  1.411130e-04  1.143990e-04  1.392331e-04
# 75%      0.004588  1.739567e-03  2.714861e-03  4.280120e-03  2.943818e-03
# max     10.154382  1.401046e+01  2.264048e+01  2.333089e+01  3.149347e+01
#
#                   6             7             8             9            10  \
# count  1.280000e+02  1.280000e+02  1.280000e+02  1.280000e+02  1.280000e+02
# mean   5.578225e-01  5.777135e-01  6.104847e-01  6.568749e-01  7.441649e-01
# ...

# %%
pr=df.profile_report()
pr.to_file(".\\spectrum_report.html")
