# %% [markdown]
# <a href="https://colab.research.google.com/github/JSJeong-me/Sound/blob/master/Wisper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai-whisper
# !pip install torch  # Required for Whisper to run

# %%
# 1. Colab에 Google Drive 마운트
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 2. gdown 설치 (Google Drive 파일 직접 다운로드용)
# !pip install -U gdown

# %%
# 3. 파일 ID 추출 및 다운로드
import gdown

# 링크: https://drive.google.com/file/d/w7/view?usp=sharing
# file_id = '1CL'
# https://drive.google.com/file/d/1gKq/view?usp=sharing
file_id = '1R'
gdown.download(f'https://drive.google.com/uc?id={file_id}', 'audio_file.wav', quiet=False)

# 4. 파일 경로 지정
audio_path = 'audio_file.wav'  # 다운받은 파일명

# 이제 아래와 같이 사용하면 됩니다.
print(f"Audio file path: {audio_path}")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1R9J9tJl8kXkW3LIQlUEjsoIY0-yrnu89
# To: /content/audio_file.wav
# 100%|██████████| 42.0M/42.0M [00:01<00:00, 33.4MB/s]
# Audio file path: audio_file.wav

# %%
import whisper

# Load the Whisper model (base is fast and decent, 'large' is most accurate but slow)
model = whisper.load_model("base")

# Path to your local audio file
# audio_path = "your_file_name_here.wav"  # Update this

# Transcribe
# result = model.transcribe(audio_path)
result = model.transcribe(audio_path, language='ko')  # for Korean

# Print the text result
print(result['text'])

# (Optional) Save to a file
with open("transcription.txt", "w", encoding="utf-8") as f:
    f.write(result['text'])
# Out:
# 100%|████████████████████████████████████████| 139M/139M [00:00<00:00, 177MiB/s]
# /usr/local/lib/python3.11/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  안녕하셨어요 예예예예 제가 그 이거를 공교를 하고요 예예 됐습니다 그 그 그 우리 그 처음으로 돌아가서 예 이 부분은 그 그 그 그 그 그 우리 그 처음으로 돌아가서 예 화면 보이시죠 예 그 8000개를 가지고서 지금 뭐 더 많아졌겠죠 그렇죠 예 예 그리고 여기서 13개 항목으로 우리가 클라스터링을 하고 예서 그 이 노문을 좀 더 자세히 제가 살펴봤어요 여기들 시리페이지에 가시면 얘네들이 재난 제거한 거랑 똑같은 방법을 썼어요 여기 보면은 이 페이스라는 백타이밍을 써서 예 그 다음에 얘네들은 이제 그 우리가 거리를 제는데 그 세 가지 방법이 있거든요 예 그래서 이제 그 신뢰 리서치라고 우리가 그 방법이 코사인 신뢰 리트 각도로 제한 방법이 있고 그 다음에 그 다 스케일이라고 갖고 이제 뭐 스케일을 작게 하는 방법도 있고 그 다음에 뉴슬리어 뉴슬리트 디스탄스라고 내가 갖고 이제 진짜 물리적인 거리를 제한 방법이 있거든요 근데 얘네들은 여기서 뉴슬리트 디스탄스를 썼어요 그러니까 이 방법하고 제가 그 여기 코드로 보내는 방법하고 여기 예 이게 거의 똑같거든요 그래서 이제 그래서 제가 질문 드리고 싶은 거는 그 여기에 그 이 코드에다가 여기 예 이 코드에다가 그 갖고 계신 그 이 8000장의 그 디타 중에 예 얼마큼 입력을 해서 테스트 해보셨는지 그게 좀 궁금해가지고 그거� 먼저 좀 답변을 주시겠어요 예 한 면을 가져가시죠 여기 그 그 그 그 그 그 그 그 그 그 지금 때 보여주시는 건 전부 다 투디의 차원 축소를 해서 그런 거잖아요. 전수투를 했잖아요. 그러면 그걸 가지고서 이제 실제 이 천력백 차원에서 거리를 한번 제거진 적은 있으세요. 그거를 클라스터링을. 그러면 그걸 해봐야죠. 지금 저게 색깔 부분도 전혀 안 되네요. 둘 다요. 저게 유의미한지, 무의미한지 구분이 안 가네요. 아니요. 각각의 컵버너들이. 그러니까 제가 여기 갖고 있는 이런 거 하는 교환이 있는데 각각 여기서 백타지비라는 게. 지금 저희가 이미지를 갖다가 넣게 되면 이게 다 택스트 같은 경우는 코드로 바뀌잖아요. 근데 이미지에서 지금 우리가 코드로 바뀌는 거는 여기다가 대한민국. 독도. 우리 땅. 이렇게 하면 이게 코드 값을 이렇게 바뀌는 거거든요. 그 자가 그쵸? 예 예 예. 근데 지금 우리는 이게 뭐냐 하면 여기에서 이게 뭐냐 하면 우리는 이미지가 레슨의 오공에 들어가서 그게 소프트 맥스로 참기 황률값으로 이게 임베딩이 되는 거거든요. 그래서 그게 이제 임베딩이 이렇게 숫자로 되면 이게 과일은 과일길이 그 다음에 이렇게 그 배는 백길이 이렇게 모이단 말이에요. 그래서 여기 배가 모인다 그랬을 때 이게 가라져 있으면 이게 사람 밴지 타는 밴지 저는 모르잖아요. 먹면 밴지. 그래서 이게 임베딩이 돼 가지고 백타지비라는 과일은 과일길이 그 다음에 잠수함 종입에 이렇게 해서 이게 서로 나뉘어져요. 그래서 이제 그 예를 들어서 여기에 정상 그 다음에 낮고 이렇게 나뉘어진단 말이에요. 그러니까 천임백 차원에서 그러면 그걸 가지고 우리가 이거를 갖다 유사도를 갖다가 체크�해야 되는데 여기 배에 그러면 이게 이 거리를 재는 게 유크리드 디스탄 쓰거든요. 아니면 각도를 재는 게 코산 스밀을 를 띄고 이 각도. 그래서 지금 이제 그러면 여기까지 하셨으면 지금 다음 단계를 해야 될 거로 뭐냐 하면 이 스밀을 체크�해야 돼요. 그래서 그 특정한 얘가 되는 패턴에 대해서 그게 구시됐던 낮구시됐던 아까 뭐 CRTF가 내건 아이시가 내건 거기서 어떤 그 구시됐던 낮구시던 찾는 패턴하고 다른 애들과의 거리를 재야 되거든요. 그래서 그 거리를 재는 방법이 여기 코산 스밀을 띄고 그다음에 스케일 뜯어 그다음에 그러니까 유크리드 디스턴스 해 가지고 디스턴스를 재는 방법이 있거든요. 이걸 갖다 우리가 L2 노밀하고 로제 L2 너무 이거 세계 중에 하나 갖고 이제 거리를 재야 돼요. 그래서 첫 번째로는 지금 이제 우리가 했던 그 영상들을 가지고서 얘네들이 이렇게 구루핑이 되어 있는 지를 확연해야 되거든요. 지금 우리는 그 사람이 1000주백 차원을 갖다가 우리가 상상타지 못하잖아요. 그래서 그걸 2차원으로 지금 해 놓은 것대 그거를 색깔만 좀 다르게 해야 한다 하더라도 아마 이게 구루핑이 되는 것들을 패턴을 볼 수가 있을 것 같은데 이거를 갖다가 단계를 하는 방법도 있거든요. 어떻게 하냐면 백탈디류로 바로 가지 말고 이거를 임베딩을 한 다음에 백탈디류로 하는 방법이 있어요. 그러니까 그렇죠 그렇죠 그렇죠. 그래서 여기 그 과정이 얘가 어디에 있냐면 조금만 찾아볼게요. 오픈의 이 아이의 임베딩에 그 여기에 가면 백타이 빼딩 가면 예제가 있어요. 여기 보면 여기 제가 이거를 유화를 보내드릴게요. 지금部分 � Right reopen type trait same 줄でしょう 여기로 와 보세요. 예 여기로 1981 pr 예 여기로 오면 요렇게 콧가 그대로 있어요. 여기 임베딩하는 방법이 있고 여기 잡아 그 팔선으로 가면은 임베딩하는 방법이 있고 그 다음에 여기에 아 이거 이제 그 여기까지는 상관이 없어요 여기까지는 지금 이제 그 텍스트 임베딩 모델이니까 이거를 갖고 그 임베딩 한 걸 갖고 와서 그럼 임베딩 한 번 이렇게 뭐가 됐냐면은 그 우리는 참개의 csb 값이 될 거예요 csb 값을 갖고 참개의 값들이 이렇게 한국 값으로 이렇게 나오게 되는데 여기에 이제 여기서 이제 그 이 차오물을 하고 차오물 축소를 갖고 보여준다는 그 얘기고 여기에 보면은 그리고 캐스텔 엔서리인이라는 게 뭐냐면 이게 거리로서 이제 그 이 코사 스릴러를 들이게 얼마나 가까운지를 알 수 있냐 없냐 뭐 요거는 것들을 보여주는 거거든요 자, 근데 여기는 지금 텍스트고 우리는 이미지 그 차이 밖에 없어요 그래서 여기 보면은 즉 그 이 예를 갖고 이제 그 이걸 찬난 방법들이 있는 거죠 여기 보면은 여기 얘는 그 코사 스릴러를 들을 적고 있죠 그렇죠 그러면은 그 이 코드를 제가 지금 그 아까 볼 수 있는 영상에서 그 검색할 수 있는 코드를 하나 만들어드릴까요 예 예 예 네 그렇죠 상대비 교이 상대비였네 예 이거를 이제 그 그런 머신나닝하고는 지금 거리가 좀 다른 얘기고 우리는 그 300, 그 1600 차원에다가 지금 각국의 이미지를 갖고서 얘네들이 비슷한 일기를 갖다가 이렇게 뭉쳐놓은 거예요. 어떤 개념이냐면 지금 우리는 이걸 투디로 바꿔서 그런데 여기에 보면은 GPT4 올 이렇게 가면은 여기에 보면 여기에 이게 뭐냐 하면은 우리가 위키피티 아시죠 그 깊이 디아 그 뇌크 전화를 그거를 갖다가 그 임베닝함 이렇게 됐는 거예요. 그러니까 지금 우리가 8000개의 이미지를 임베닝하면은 이런 상태로 되어있는 거예요. 그래서 여기 보면은 다퀴먼 매니지 먼튼은 다퀴먼 매니지 먼튼이 이렇게 모여있고 스터디는 스터디게리로 모여있고 프로그램 랭기지는 프로그램 랭기 직기를 모여있는 거예요. 그러니까 지금 우리 8000개의 이미지도 그게 지금 투디로 바닥으로는 거지 공간에 그 1000,600 차원에 이렇게 지를끼리 이렇게 모여있는 거예요. 게임 데뷔를 본 게임 데뷔를 보러 오고 이게 뭉쳐있는 거죠 1000,600 차원에 지를끼리 거리가 그렇지, 그렇지 그게 황금값은 예예예예예. 그래서 더 정교하게 하려면은 그 레스데도 오고옹을 갖고서 그 트렀스포러닝을 하면 정말 정교하게 그 모아모сп가 있을 것 같거든요. 피처를 뽑아서 트레스���러님을 해서 거기다 모드를 바깥치기라면 그 코드는 엄청나게 쉽죠? 여기에 이것만 트레스���러님을 하면 되니까 여기 얘만 얘만 트레스���러님을 하면 되니까 그래서 굉장히 정교하게 얘를 갖다가 이렇게 다쳐온 공간에다가 이렇게 우리가 임배딩을 할 수가 있어요 그리고 걔네들에 대해서 라별림화 붙여주면 되는 거예요 이게 낙고시냐고시냐 아니면 이게 아까 뭐 CRTB, FB, IC냐 이것만 구루핑을 해 주면 되는 거죠 사실 구루핑도 아니라 확인만 하는 거죠, 확인만 그렇죠, 그렇죠 그렇죠 계속 그 네 말씀하세요 그렇죠 그럼 이제 그 때는 클래스를 갖다가 제가 알기로는 여기에 지금 열쇠기 항목으로 고근하겠다고 하시는 거 아니에요 아 그래요 그러면 이상탐지까지 해가지고 그게 뭐 뭐 청계를 안 될 거 아니에요 그렇죠? 뭐 기껏 해봤자 뵐게 사실  ...
